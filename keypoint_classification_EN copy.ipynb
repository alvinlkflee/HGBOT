# %%
import csv
import os
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42

# %% [markdown]
# # Specify each path

# %%
dataset = 'model/keypoint_classifier/keypoint.csv'
model_save_path = 'model/keypoint_classifier/keypoint_classifier.hdf5'
tflite_save_path = 'model/keypoint_classifier/keypoint_classifier.tflite'

# %% [markdown]
# # Set number of classes

# %%
NUM_CLASSES = 6

# %% [markdown]
# # Dataset reading

# %%
try:
    if not os.path.exists(dataset):
        raise FileNotFoundError(f"Dataset not found at path: {dataset}")

    # Load dataset
    X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1)))
    y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

    if X_dataset.shape[0] == 0 or y_dataset.shape[0] == 0:
        raise ValueError("Dataset is empty.")

    if X_dataset.shape[0] != y_dataset.shape[0]:
        raise ValueError("Mismatch in feature and label dataset sizes.")

except FileNotFoundError as e:
    print(e)
    exit()
except ValueError as e:
    print(f"Error with dataset: {e}")
    exit()
except Exception as e:
    print(f"Unexpected error loading dataset: {e}")
    exit()

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)

# %% [markdown]
# # Model building

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((21 * 2, )),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(20, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
])

# %%
model.summary()  # tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dropout (Dropout)           (None, 42)                0
#
#  dense (Dense)               (None, 20)                860
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 6)                 66
#
# =================================================================
# Total params: 1136 (4.44 KB)
# Trainable params: 1136 (4.44 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Model checkpoint callback
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
# Callback for early stopping
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)

# %%
# Model compilation
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # Model training

# %%
# Check data shapes
assert X_train.shape[0] == y_train.shape[0], "Mismatch in number of samples between X_train and y_train"
assert X_test.shape[0] == y_test.shape[0], "Mismatch in number of samples between X_test and y_test"

try:
    # Train the model
    model.fit(
        X_train,
        y_train,
        epochs=1000,
        batch_size=128,
        validation_data=(X_test, y_test),
        callbacks=[cp_callback, es_callback]
    )

except MemoryError:
    print("Out-of-memory error encountered. Consider reducing the batch size or using a smaller dataset.")
# Out:
# Epoch 1/1000
# 20/41 [=============>................] - ETA: 0s - loss: 1.8961 - accuracy: 0.1297
# Epoch 1: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 2s 15ms/step - loss: 1.8523 - accuracy: 0.1560 - val_loss: 1.7560 - val_accuracy: 0.2713
# Epoch 2/1000
# 40/41 [============================>.] - ETA: 0s - loss: 1.7384 - accuracy: 0.2467
# C:\Users\USER\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 1.7375 - accuracy: 0.2484 - val_loss: 1.6752 - val_accuracy: 0.3741
# Epoch 3/1000
# 24/41 [================>.............] - ETA: 0s - loss: 1.6899 - accuracy: 0.2959
# Epoch 3: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.6816 - accuracy: 0.3023 - val_loss: 1.5762 - val_accuracy: 0.4603
# Epoch 4/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 1.6223 - accuracy: 0.3349
# Epoch 4: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.6118 - accuracy: 0.3437 - val_loss: 1.4885 - val_accuracy: 0.5345
# Epoch 5/1000
# 20/41 [=============>................] - ETA: 0s - loss: 1.5758 - accuracy: 0.3570
# Epoch 5: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.5438 - accuracy: 0.3740 - val_loss: 1.4108 - val_accuracy: 0.5299
# Epoch 6/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 1.4986 - accuracy: 0.3978
# Epoch 6: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.4934 - accuracy: 0.3954 - val_loss: 1.3391 - val_accuracy: 0.5397
# Epoch 7/1000
# 41/41 [==============================] - ETA: 0s - loss: 1.4469 - accuracy: 0.4273
# Epoch 7: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.4469 - accuracy: 0.4273 - val_loss: 1.2698 - val_accuracy: 0.5730
# Epoch 8/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 1.4083 - accuracy: 0.4341
# Epoch 8: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.4015 - accuracy: 0.4416 - val_loss: 1.2047 - val_accuracy: 0.6023
# Epoch 9/1000
# 24/41 [================>.............] - ETA: 0s - loss: 1.3621 - accuracy: 0.4587
# Epoch 9: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.3594 - accuracy: 0.4618 - val_loss: 1.1434 - val_accuracy: 0.6333
# Epoch 10/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 1.3284 - accuracy: 0.4755
# Epoch 10: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.3238 - accuracy: 0.4830 - val_loss: 1.0821 - val_accuracy: 0.6810
# Epoch 11/1000
# 22/41 [===============>..............] - ETA: 0s - loss: 1.2898 - accuracy: 0.4968
# Epoch 11: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.2845 - accuracy: 0.5003 - val_loss: 1.0258 - val_accuracy: 0.7144
# Epoch 12/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 1.2629 - accuracy: 0.4993
# Epoch 12: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.2637 - accuracy: 0.5024 - val_loss: 0.9833 - val_accuracy: 0.7575
# Epoch 13/1000
# 39/41 [===========================>..] - ETA: 0s - loss: 1.2021 - accuracy: 0.5417
# Epoch 13: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 7ms/step - loss: 1.2074 - accuracy: 0.5388 - val_loss: 0.9289 - val_accuracy: 0.7667
# Epoch 14/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 1.1923 - accuracy: 0.5459
# Epoch 14: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.1846 - accuracy: 0.5434 - val_loss: 0.8849 - val_accuracy: 0.7736
# Epoch 15/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 1.1578 - accuracy: 0.5489
# Epoch 15: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.1595 - accuracy: 0.5465 - val_loss: 0.8526 - val_accuracy: 0.7948
# Epoch 16/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 1.1539 - accuracy: 0.5547
# Epoch 16: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.1445 - accuracy: 0.5612 - val_loss: 0.8233 - val_accuracy: 0.7971
# Epoch 17/1000
# 20/41 [=============>................] - ETA: 0s - loss: 1.1178 - accuracy: 0.5742
# Epoch 17: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.1004 - accuracy: 0.5806 - val_loss: 0.7839 - val_accuracy: 0.8224
# Epoch 18/1000
# 22/41 [===============>..............] - ETA: 0s - loss: 1.1035 - accuracy: 0.5799
# Epoch 18: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.1036 - accuracy: 0.5833 - val_loss: 0.7706 - val_accuracy: 0.8115
# Epoch 19/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 1.0730 - accuracy: 0.5904
# Epoch 19: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.0742 - accuracy: 0.5879 - val_loss: 0.7334 - val_accuracy: 0.8287
# Epoch 20/1000
# 24/41 [================>.............] - ETA: 0s - loss: 1.0589 - accuracy: 0.5970
# Epoch 20: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.0646 - accuracy: 0.5896 - val_loss: 0.7112 - val_accuracy: 0.8385
# Epoch 21/1000
# 22/41 [===============>..............] - ETA: 0s - loss: 1.0607 - accuracy: 0.5991
# Epoch 21: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.0414 - accuracy: 0.6034 - val_loss: 0.6955 - val_accuracy: 0.8368
# Epoch 22/1000
# 24/41 [================>.............] - ETA: 0s - loss: 1.0472 - accuracy: 0.5990
# Epoch 22: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.0312 - accuracy: 0.6074 - val_loss: 0.6750 - val_accuracy: 0.8443
# Epoch 23/1000
# 22/41 [===============>..............] - ETA: 0s - loss: 1.0510 - accuracy: 0.5962
# Epoch 23: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.0207 - accuracy: 0.6092 - val_loss: 0.6600 - val_accuracy: 0.8414
# Epoch 24/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 1.0367 - accuracy: 0.6034
# Epoch 24: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 1.0273 - accuracy: 0.6122 - val_loss: 0.6453 - val_accuracy: 0.8592
# Epoch 25/1000
# 25/41 [=================>............] - ETA: 0s - loss: 1.0094 - accuracy: 0.6131
# Epoch 25: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.9989 - accuracy: 0.6176 - val_loss: 0.6345 - val_accuracy: 0.8517
# Epoch 26/1000
# 26/41 [==================>...........] - ETA: 0s - loss: 0.9917 - accuracy: 0.6244
# Epoch 26: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 8ms/step - loss: 0.9917 - accuracy: 0.6266 - val_loss: 0.6303 - val_accuracy: 0.8540
# Epoch 27/1000
# 41/41 [==============================] - ETA: 0s - loss: 0.9851 - accuracy: 0.6251
# Epoch 27: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.9851 - accuracy: 0.6251 - val_loss: 0.6097 - val_accuracy: 0.8672
# Epoch 28/1000
# 32/41 [======================>.......] - ETA: 0s - loss: 0.9700 - accuracy: 0.6292
# Epoch 28: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.9667 - accuracy: 0.6312 - val_loss: 0.6020 - val_accuracy: 0.8672
# Epoch 29/1000
# 31/41 [=====================>........] - ETA: 0s - loss: 1.0001 - accuracy: 0.6051
# Epoch 29: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 7ms/step - loss: 0.9868 - accuracy: 0.6105 - val_loss: 0.6017 - val_accuracy: 0.8603
# Epoch 30/1000
# 35/41 [========================>.....] - ETA: 0s - loss: 0.9565 - accuracy: 0.6393
# Epoch 30: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 7ms/step - loss: 0.9545 - accuracy: 0.6360 - val_loss: 0.5812 - val_accuracy: 0.8661
# Epoch 31/1000
# 33/41 [=======================>......] - ETA: 0s - loss: 0.9469 - accuracy: 0.6406
# Epoch 31: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.9604 - accuracy: 0.6339 - val_loss: 0.5745 - val_accuracy: 0.8747
# Epoch 32/1000
# 33/41 [=======================>......] - ETA: 0s - loss: 0.9638 - accuracy: 0.6375
# Epoch 32: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 7ms/step - loss: 0.9632 - accuracy: 0.6377 - val_loss: 0.5728 - val_accuracy: 0.8747
# Epoch 33/1000
# 33/41 [=======================>......] - ETA: 0s - loss: 0.9417 - accuracy: 0.6378
# Epoch 33: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.9311 - accuracy: 0.6394 - val_loss: 0.5605 - val_accuracy: 0.8805
# Epoch 34/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 0.9488 - accuracy: 0.6457
# Epoch 34: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.9466 - accuracy: 0.6439 - val_loss: 0.5461 - val_accuracy: 0.8868
# Epoch 35/1000
# 40/41 [============================>.] - ETA: 0s - loss: 0.9600 - accuracy: 0.6367
# Epoch 35: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 7ms/step - loss: 0.9607 - accuracy: 0.6364 - val_loss: 0.5466 - val_accuracy: 0.8851
# Epoch 36/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.9378 - accuracy: 0.6425
# Epoch 36: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.9317 - accuracy: 0.6419 - val_loss: 0.5431 - val_accuracy: 0.8874
# Epoch 37/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.9119 - accuracy: 0.6488
# Epoch 37: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.9140 - accuracy: 0.6531 - val_loss: 0.5256 - val_accuracy: 0.8920
# Epoch 38/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 0.9083 - accuracy: 0.6556
# Epoch 38: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.9189 - accuracy: 0.6536 - val_loss: 0.5223 - val_accuracy: 0.8897
# Epoch 39/1000
# 24/41 [================>.............] - ETA: 0s - loss: 0.9455 - accuracy: 0.6416
# Epoch 39: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.9378 - accuracy: 0.6513 - val_loss: 0.5217 - val_accuracy: 0.8931
# Epoch 40/1000
# 24/41 [================>.............] - ETA: 0s - loss: 0.9036 - accuracy: 0.6615
# Epoch 40: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.9104 - accuracy: 0.6517 - val_loss: 0.5202 - val_accuracy: 0.8885
# Epoch 41/1000
# 24/41 [================>.............] - ETA: 0s - loss: 0.9012 - accuracy: 0.6468
# Epoch 41: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.9064 - accuracy: 0.6494 - val_loss: 0.5125 - val_accuracy: 0.8937
# Epoch 42/1000
# 25/41 [=================>............] - ETA: 0s - loss: 0.9213 - accuracy: 0.6569
# Epoch 42: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.9206 - accuracy: 0.6573 - val_loss: 0.5095 - val_accuracy: 0.8948
# Epoch 43/1000
# 26/41 [==================>...........] - ETA: 0s - loss: 0.8947 - accuracy: 0.6659
# Epoch 43: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8918 - accuracy: 0.6636 - val_loss: 0.5036 - val_accuracy: 0.8977
# Epoch 44/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.8911 - accuracy: 0.6570
# Epoch 44: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8924 - accuracy: 0.6607 - val_loss: 0.4911 - val_accuracy: 0.8943
# Epoch 45/1000
# 24/41 [================>.............] - ETA: 0s - loss: 0.8949 - accuracy: 0.6484
# Epoch 45: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.9015 - accuracy: 0.6529 - val_loss: 0.4980 - val_accuracy: 0.8977
# Epoch 46/1000
# 40/41 [============================>.] - ETA: 0s - loss: 0.8968 - accuracy: 0.6574
# Epoch 46: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8955 - accuracy: 0.6580 - val_loss: 0.4944 - val_accuracy: 0.8983
# Epoch 47/1000
# 40/41 [============================>.] - ETA: 0s - loss: 0.8964 - accuracy: 0.6564
# Epoch 47: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 7ms/step - loss: 0.8980 - accuracy: 0.6565 - val_loss: 0.4887 - val_accuracy: 0.8989
# Epoch 48/1000
# 26/41 [==================>...........] - ETA: 0s - loss: 0.8894 - accuracy: 0.6514
# Epoch 48: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8892 - accuracy: 0.6523 - val_loss: 0.4915 - val_accuracy: 0.9011
# Epoch 49/1000
# 22/41 [===============>..............] - ETA: 0s - loss: 0.9064 - accuracy: 0.6566
# Epoch 49: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8874 - accuracy: 0.6630 - val_loss: 0.4793 - val_accuracy: 0.8989
# Epoch 50/1000
# 22/41 [===============>..............] - ETA: 0s - loss: 0.8646 - accuracy: 0.6726
# Epoch 50: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8704 - accuracy: 0.6669 - val_loss: 0.4787 - val_accuracy: 0.8977
# Epoch 51/1000
# 18/41 [============>.................] - ETA: 0s - loss: 0.8896 - accuracy: 0.6641
# Epoch 51: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8888 - accuracy: 0.6695 - val_loss: 0.4810 - val_accuracy: 0.8971
# Epoch 52/1000
# 25/41 [=================>............] - ETA: 0s - loss: 0.8911 - accuracy: 0.6619
# Epoch 52: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8870 - accuracy: 0.6663 - val_loss: 0.4763 - val_accuracy: 0.8983
# Epoch 53/1000
# 20/41 [=============>................] - ETA: 0s - loss: 0.8906 - accuracy: 0.6590
# Epoch 53: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8677 - accuracy: 0.6707 - val_loss: 0.4615 - val_accuracy: 0.9080
# Epoch 54/1000
# 26/41 [==================>...........] - ETA: 0s - loss: 0.8852 - accuracy: 0.6707
# Epoch 54: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8875 - accuracy: 0.6715 - val_loss: 0.4651 - val_accuracy: 0.9075
# Epoch 55/1000
# 26/41 [==================>...........] - ETA: 0s - loss: 0.8819 - accuracy: 0.6647
# Epoch 55: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8750 - accuracy: 0.6659 - val_loss: 0.4640 - val_accuracy: 0.9029
# Epoch 56/1000
# 24/41 [================>.............] - ETA: 0s - loss: 0.8836 - accuracy: 0.6722
# Epoch 56: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8657 - accuracy: 0.6801 - val_loss: 0.4621 - val_accuracy: 0.8966
# Epoch 57/1000
# 20/41 [=============>................] - ETA: 0s - loss: 0.8894 - accuracy: 0.6613
# Epoch 57: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8772 - accuracy: 0.6732 - val_loss: 0.4570 - val_accuracy: 0.9052
# Epoch 58/1000
# 24/41 [================>.............] - ETA: 0s - loss: 0.9028 - accuracy: 0.6501
# Epoch 58: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8837 - accuracy: 0.6621 - val_loss: 0.4638 - val_accuracy: 0.9011
# Epoch 59/1000
# 34/41 [=======================>......] - ETA: 0s - loss: 0.8713 - accuracy: 0.6714
# Epoch 59: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.8711 - accuracy: 0.6761 - val_loss: 0.4491 - val_accuracy: 0.9075
# Epoch 60/1000
# 38/41 [==========================>...] - ETA: 0s - loss: 0.8461 - accuracy: 0.6782
# Epoch 60: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8470 - accuracy: 0.6778 - val_loss: 0.4486 - val_accuracy: 0.9052
# Epoch 61/1000
# 34/41 [=======================>......] - ETA: 0s - loss: 0.8602 - accuracy: 0.6735
# Epoch 61: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8670 - accuracy: 0.6724 - val_loss: 0.4478 - val_accuracy: 0.9029
# Epoch 62/1000
# 24/41 [================>.............] - ETA: 0s - loss: 0.8889 - accuracy: 0.6787
# Epoch 62: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8726 - accuracy: 0.6755 - val_loss: 0.4466 - val_accuracy: 0.9052
# Epoch 63/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 0.8648 - accuracy: 0.6668
# Epoch 63: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 4ms/step - loss: 0.8760 - accuracy: 0.6624 - val_loss: 0.4518 - val_accuracy: 0.9006
# Epoch 64/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 0.8903 - accuracy: 0.6617
# Epoch 64: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8800 - accuracy: 0.6642 - val_loss: 0.4524 - val_accuracy: 0.9034
# Epoch 65/1000
# 20/41 [=============>................] - ETA: 0s - loss: 0.8558 - accuracy: 0.6684
# Epoch 65: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8502 - accuracy: 0.6805 - val_loss: 0.4485 - val_accuracy: 0.9017
# Epoch 66/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 0.8434 - accuracy: 0.6780
# Epoch 66: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8453 - accuracy: 0.6778 - val_loss: 0.4350 - val_accuracy: 0.9063
# Epoch 67/1000
# 22/41 [===============>..............] - ETA: 0s - loss: 0.8555 - accuracy: 0.6808
# Epoch 67: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8564 - accuracy: 0.6764 - val_loss: 0.4474 - val_accuracy: 0.9075
# Epoch 68/1000
# 24/41 [================>.............] - ETA: 0s - loss: 0.8218 - accuracy: 0.6794
# Epoch 68: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8406 - accuracy: 0.6803 - val_loss: 0.4391 - val_accuracy: 0.9075
# Epoch 69/1000
# 26/41 [==================>...........] - ETA: 0s - loss: 0.8597 - accuracy: 0.6869
# Epoch 69: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8613 - accuracy: 0.6833 - val_loss: 0.4439 - val_accuracy: 0.9075
# Epoch 70/1000
# 40/41 [============================>.] - ETA: 0s - loss: 0.8475 - accuracy: 0.6814
# Epoch 70: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 7ms/step - loss: 0.8465 - accuracy: 0.6814 - val_loss: 0.4411 - val_accuracy: 0.9098
# Epoch 71/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 0.8151 - accuracy: 0.6919
# Epoch 71: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8317 - accuracy: 0.6879 - val_loss: 0.4232 - val_accuracy: 0.9167
# Epoch 72/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.8466 - accuracy: 0.6767
# Epoch 72: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8493 - accuracy: 0.6755 - val_loss: 0.4286 - val_accuracy: 0.9109
# Epoch 73/1000
# 24/41 [================>.............] - ETA: 0s - loss: 0.8490 - accuracy: 0.6777
# Epoch 73: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8513 - accuracy: 0.6778 - val_loss: 0.4315 - val_accuracy: 0.9086
# Epoch 74/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 0.8326 - accuracy: 0.6804
# Epoch 74: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8444 - accuracy: 0.6795 - val_loss: 0.4315 - val_accuracy: 0.9092
# Epoch 75/1000
# 20/41 [=============>................] - ETA: 0s - loss: 0.8297 - accuracy: 0.6988
# Epoch 75: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8232 - accuracy: 0.6933 - val_loss: 0.4268 - val_accuracy: 0.9075
# Epoch 76/1000
# 24/41 [================>.............] - ETA: 0s - loss: 0.8322 - accuracy: 0.6878
# Epoch 76: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8388 - accuracy: 0.6904 - val_loss: 0.4243 - val_accuracy: 0.9103
# Epoch 77/1000
# 20/41 [=============>................] - ETA: 0s - loss: 0.8047 - accuracy: 0.6988
# Epoch 77: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 4ms/step - loss: 0.8403 - accuracy: 0.6824 - val_loss: 0.4250 - val_accuracy: 0.9126
# Epoch 78/1000
# 20/41 [=============>................] - ETA: 0s - loss: 0.8514 - accuracy: 0.6895
# Epoch 78: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8454 - accuracy: 0.6872 - val_loss: 0.4255 - val_accuracy: 0.9103
# Epoch 79/1000
# 24/41 [================>.............] - ETA: 0s - loss: 0.8459 - accuracy: 0.6813
# Epoch 79: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8437 - accuracy: 0.6816 - val_loss: 0.4321 - val_accuracy: 0.9132
# Epoch 80/1000
# 24/41 [================>.............] - ETA: 0s - loss: 0.8137 - accuracy: 0.6940
# Epoch 80: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8258 - accuracy: 0.6895 - val_loss: 0.4226 - val_accuracy: 0.9138
# Epoch 81/1000
# 31/41 [=====================>........] - ETA: 0s - loss: 0.8281 - accuracy: 0.6998
# Epoch 81: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.8442 - accuracy: 0.6908 - val_loss: 0.4210 - val_accuracy: 0.9126
# Epoch 82/1000
# 36/41 [=========================>....] - ETA: 0s - loss: 0.8295 - accuracy: 0.6901
# Epoch 82: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8385 - accuracy: 0.6858 - val_loss: 0.4233 - val_accuracy: 0.9109
# Epoch 83/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.8268 - accuracy: 0.6938
# Epoch 83: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8335 - accuracy: 0.6922 - val_loss: 0.4159 - val_accuracy: 0.9184
# Epoch 84/1000
# 41/41 [==============================] - ETA: 0s - loss: 0.8363 - accuracy: 0.6927
# Epoch 84: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8363 - accuracy: 0.6927 - val_loss: 0.4222 - val_accuracy: 0.9144
# Epoch 85/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.8019 - accuracy: 0.7042
# Epoch 85: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8136 - accuracy: 0.6952 - val_loss: 0.4136 - val_accuracy: 0.9109
# Epoch 86/1000
# 41/41 [==============================] - ETA: 0s - loss: 0.8333 - accuracy: 0.6855
# Epoch 86: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8333 - accuracy: 0.6855 - val_loss: 0.4163 - val_accuracy: 0.9092
# Epoch 87/1000
# 20/41 [=============>................] - ETA: 0s - loss: 0.8269 - accuracy: 0.6984
# Epoch 87: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8315 - accuracy: 0.6918 - val_loss: 0.4257 - val_accuracy: 0.9149
# Epoch 88/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.8262 - accuracy: 0.6834
# Epoch 88: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8322 - accuracy: 0.6858 - val_loss: 0.4198 - val_accuracy: 0.9195
# Epoch 89/1000
# 41/41 [==============================] - ETA: 0s - loss: 0.8260 - accuracy: 0.6843
# Epoch 89: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8260 - accuracy: 0.6843 - val_loss: 0.4124 - val_accuracy: 0.9178
# Epoch 90/1000
# 34/41 [=======================>......] - ETA: 0s - loss: 0.8259 - accuracy: 0.6905
# Epoch 90: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 9ms/step - loss: 0.8176 - accuracy: 0.6935 - val_loss: 0.4110 - val_accuracy: 0.9213
# Epoch 91/1000
# 27/41 [==================>...........] - ETA: 0s - loss: 0.8191 - accuracy: 0.6907
# Epoch 91: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s
saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7936 - accuracy: 0.7060 - val_loss: 0.4000 - val_accuracy: 0.9195
# Epoch 106/1000
# 41/41 [==============================] - ETA: 0s - loss: 0.8104 - accuracy: 0.6971
# Epoch 106: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8104 - accuracy: 0.6971 - val_loss: 0.4044 - val_accuracy: 0.9178
# Epoch 107/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.7928 - accuracy: 0.7121
# Epoch 107: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8148 - accuracy: 0.6970 - val_loss: 0.3908 - val_accuracy: 0.9195
# Epoch 108/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.7906 - accuracy: 0.7016
# Epoch 108: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.7971 - accuracy: 0.6996 - val_loss: 0.3969 - val_accuracy: 0.9195
# Epoch 109/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.8023 - accuracy: 0.6979
# Epoch 109: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8012 - accuracy: 0.6933 - val_loss: 0.3960 - val_accuracy: 0.9224
# Epoch 110/1000
# 20/41 [=============>................] - ETA: 0s - loss: 0.8292 - accuracy: 0.6910
# Epoch 110: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8134 - accuracy: 0.6966 - val_loss: 0.3998 - val_accuracy: 0.9218
# Epoch 111/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 0.7798 - accuracy: 0.7133
# Epoch 111: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7901 - accuracy: 0.7104 - val_loss: 0.3912 - val_accuracy: 0.9190
# Epoch 112/1000
# 22/41 [===============>..............] - ETA: 0s - loss: 0.7925 - accuracy: 0.7127
# Epoch 112: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8030 - accuracy: 0.7008 - val_loss: 0.3983 - val_accuracy: 0.9241
# Epoch 113/1000
# 24/41 [================>.............] - ETA: 0s - loss: 0.8055 - accuracy: 0.6930
# Epoch 113: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7951 - accuracy: 0.6968 - val_loss: 0.3906 - val_accuracy: 0.9224
# Epoch 114/1000
# 19/41 [============>.................] - ETA: 0s - loss: 0.8000 - accuracy: 0.7011
# Epoch 114: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7955 - accuracy: 0.7012 - val_loss: 0.3957 - val_accuracy: 0.9195
# Epoch 115/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.8148 - accuracy: 0.6935
# Epoch 115: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8049 - accuracy: 0.6981 - val_loss: 0.3930 - val_accuracy: 0.9247
# Epoch 116/1000
# 22/41 [===============>..............] - ETA: 0s - loss: 0.8093 - accuracy: 0.7021
# Epoch 116: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8073 - accuracy: 0.7010 - val_loss: 0.4050 - val_accuracy: 0.9190
# Epoch 117/1000
# 40/41 [============================>.] - ETA: 0s - loss: 0.8121 - accuracy: 0.6938
# Epoch 117: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 8ms/step - loss: 0.8118 - accuracy: 0.6935 - val_loss: 0.3982 - val_accuracy: 0.9247
# Epoch 118/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.8125 - accuracy: 0.6942
# Epoch 118: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.8102 - accuracy: 0.6927 - val_loss: 0.3968 - val_accuracy: 0.9178
# Epoch 119/1000
# 30/41 [====================>.........] - ETA: 0s - loss: 0.8003 - accuracy: 0.6945
# Epoch 119: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.7985 - accuracy: 0.6935 - val_loss: 0.3932 - val_accuracy: 0.9201
# Epoch 120/1000
# 25/41 [=================>............] - ETA: 0s - loss: 0.7892 - accuracy: 0.6931
# Epoch 120: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0
saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.7720 - accuracy: 0.7117 - val_loss: 0.3718 - val_accuracy: 0.9241
# Epoch 148/1000
# 41/41 [==============================] - ETA: 0s - loss: 0.7583 - accuracy: 0.7205
# Epoch 148: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7583 - accuracy: 0.7205 - val_loss: 0.3706 - val_accuracy: 0.9305
# Epoch 149/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.7429 - accuracy: 0.7214
# Epoch 149: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.7580 - accuracy: 0.7209 - val_loss: 0.3781 - val_accuracy: 0.9241
# Epoch 150/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.7669 - accuracy: 0.7147
# Epoch 150: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7731 - accuracy: 0.7131 - val_loss: 0.3780 - val_accuracy: 0.9259
# Epoch 151/1000
# 30/41 [====================>.........] - ETA: 0s - loss: 0.7468 - accuracy: 0.7208
# Epoch 151: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.7626 - accuracy: 0.7173 - val_loss: 0.3783 - val_accuracy: 0.9224
# Epoch 152/1000
# 35/41 [========================>.....] - ETA: 0s - loss: 0.7623 - accuracy: 0.7127
# Epoch 152: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.7675 - accuracy: 0.7123 - val_loss: 0.3728 - val_accuracy: 0.9247
# Epoch 153/1000
# 34/41 [=======================>......] - ETA: 0s - loss: 0.7543 - accuracy: 0.7130
# Epoch 153: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.7490 - accuracy: 0.7155 - val_loss: 0.3754 - val_accuracy: 0.9293
# Epoch 154/1000
# 33/41 [=======================>......] - ETA: 0s - loss: 0.7394 - accuracy: 0.7171
# Epoch 154: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.7401 - accuracy: 0.7209 - val_loss: 0.3680 - val_accuracy: 0.9276
# Epoch 155/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.7531 - accuracy: 0.7221
# Epoch 155: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7515 - accuracy: 0.7244 - val_loss: 0.3660 - val_accuracy: 0.9316
# Epoch 156/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 0.7683 - accuracy: 0.7109
# Epoch 156: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7618 - accuracy: 0.7175 - val_loss: 0.3691 - val_accuracy: 0.9293
# Epoch 157/1000
# 38/41 [==========================>...] - ETA: 0s - loss: 0.7739 - accuracy: 0.7107
# Epoch 157: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 7ms/step - loss: 0.7753 - accuracy: 0.7102 - val_loss: 0.3819 - val_accuracy: 0.9218
# Epoch 158/1000
# 26/41 [==================>...........] - ETA: 0s - loss: 0.7545 - accuracy: 0.7269
# Epoch 158: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.7537 - accuracy: 0.7255 - val_loss: 0.3706 - val_accuracy: 0.9316
# Epoch 159/1000
# 33/41 [=======================>......] - ETA: 0s - loss: 0.7627 - accuracy: 0.7145
# Epoch 159: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7602 - accuracy: 0.7163 - val_loss: 0.3674 - val_accuracy: 0.9230
# Epoch 160/1000
# 32/41 [======================>.......] - ETA: 0s - loss: 0.7331 - accuracy: 0.7288
# Epoch 160: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.7447 - accuracy: 0.7272 - val_loss: 0.3607 - val_accuracy: 0.9345
# Epoch 161/1000
# 37/41 [==========================>...] - ETA: 0s - loss: 0.7599 - accuracy: 0.7101
# Epoch 161: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7620 - accuracy: 0.7096 - val_loss: 0.3684 - val_accuracy: 0.9339
# Epoch 162/1000
# 33/41 [=======================>......] - ETA: 0s - loss: 0.7549 - accuracy: 0.7145
# Epoch 162: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.7530 - accuracy: 0.7125 - val_loss: 0.3671 - val_accuracy: 0.9293
# Epoch 163/1000
# 36/41 [=========================>....] - ETA: 0s - loss: 0.7694 - accuracy: 0.7190
# Epoch 163: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 7ms/step - loss: 0.7664 - accuracy: 0.7184 - val_loss: 0.3752 - val_accuracy: 0.9293
# Epoch 164/1000
# 19/41 [============>.................] - ETA: 0s - loss: 0.7480 - accuracy: 0.7290
# Epoch 164: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7436 - accuracy: 0.7255 - val_loss: 0.3718 - val_accuracy: 0.9224
# Epoch 165/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 0.7724 - accuracy: 0.7174
# Epoch 165: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7724 - accuracy: 0.7159 - val_loss: 0.3683 - val_accuracy: 0.9236
# Epoch 166/1000
# 19/41 [============>.................] - ETA: 0s - loss: 0.7707 - accuracy: 0.7122
# Epoch 166: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7658 - accuracy: 0.7088 - val_loss: 0.3673 - val_accuracy: 0.9333
# Epoch 167/1000
# 22/41 [===============>..............] - ETA: 0s - loss: 0.7304 - accuracy: 0.7273
# Epoch 167: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7446 - accuracy: 0.7201 - val_loss: 0.3641 - val_accuracy: 0.9310
# Epoch 168/1000
# 18/41 [============>.................] - ETA: 0s - loss: 0.7542 - accuracy: 0.7218
# Epoch 168: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7484 - accuracy: 0.7232 - val_loss: 0.3661 - val_accuracy: 0.9276
# Epoch 169/1000
# 22/41 [===============>..............] - ETA: 0s - loss: 0.7659 - accuracy: 0.7170
# Epoch 169: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7592 - accuracy: 0.7246 - val_loss: 0.3659 - val_accuracy: 0.9247
# Epoch 170/1000
# 23/41 [===============>..............] - ETA: 0s - loss: 0.7682 - accuracy: 0.7174
# Epoch 170: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7592 - accuracy: 0.7213 - val_loss: 0.3677 - val_accuracy: 0.9316
# Epoch 171/1000
# 37/41 [==========================>...] - ETA: 0s - loss: 0.7515 - accuracy: 0.7145
# Epoch 171: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 7ms/step - loss: 0.7589 - accuracy: 0.7106 - val_loss: 0.3629 - val_accuracy: 0.9276
# Epoch 172/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.7338 - accuracy: 0.7206
# Epoch 172: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7570 - accuracy: 0.7152 - val_loss: 0.3714 - val_accuracy: 0.9282
# Epoch 173/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.7464 - accuracy: 0.7366
# Epoch 173: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7315 - accuracy: 0.7376 - val_loss: 0.3694 - val_accuracy: 0.9270
# Epoch 174/1000
# 24/41 [================>.............] - ETA: 0s - loss: 0.7450 - accuracy: 0.7246
# Epoch 174: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7582 - accuracy: 0.7184 - val_loss: 0.3681 - val_accuracy: 0.9282
# Epoch 175/1000
# 26/41 [==================>...........] - ETA: 0s - loss: 0.7463 - accuracy: 0.7227
# Epoch 175: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7540 - accuracy: 0.7190 - val_loss: 0.3693 - val_accuracy: 0.9379
# Epoch 176/1000
# 26/41 [==================>...........] - ETA: 0s - loss: 0.7770 - accuracy: 0.7016
# Epoch 176: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7696 - accuracy: 0.7060 - val_loss: 0.3751 - val_accuracy: 0.9230
# Epoch 177/1000
# 22/41 [===============>..............] - ETA: 0s - loss: 0.7574 - accuracy: 0.7177
# Epoch 177: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7649 - accuracy: 0.7129 - val_loss: 0.3653 - val_accuracy: 0.9207
# Epoch 178/1000
# 26/41 [==================>...........] - ETA: 0s - loss: 0.7695 - accuracy: 0.7130
# Epoch 178: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7625 - accuracy: 0.7184 - val_loss: 0.3640 - val_accuracy: 0.9310
# Epoch 179/1000
# 29/41 [====================>.........] - ETA: 0s - loss: 0.7723 - accuracy: 0.7155
# Epoch 179: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 6ms/step - loss: 0.7661 - accuracy: 0.7108 - val_loss: 0.3652 - val_accuracy: 0.9351
# Epoch 180/1000
# 21/41 [==============>...............] - ETA: 0s - loss: 0.7582 - accuracy: 0.7132
# Epoch 180: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 41/41 [==============================] - 0s 5ms/step - loss: 0.7538 - accuracy: 0.7177 - val_loss: 0.3634 - val_accuracy: 0.9282
# Epoch 180: early stopping

# %%
# Model evaluation
val_loss, val_acc = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3634 - accuracy: 0.9282

# %%
# Loading the saved model
model = tf.keras.models.load_model(model_save_path)

# %%
# Inference test
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))
# Out:
# 1/1 [==============================] - 0s 121ms/step
# [1.5796074e-01 2.8593255e-02 1.2935599e-04 3.5785150e-02 7.7683473e-01
#  6.9672370e-04]
# 4

# %% [markdown]
# # Confusion matrix

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()
    
    if report:
        print('Classification Report')
        print(classification_report(y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(y_test, y_pred)
# Out:
# 55/55 [==============================] - 0s 3ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.97      0.80      0.88       410
#            1       0.97      0.95      0.96       391
#            2       0.93      0.97      0.95       335
#            3       0.97      0.97      0.97       117
#            4       0.74      0.99      0.85       221
#            5       0.99      0.97      0.98       266
#
#     accuracy                           0.93      1740
#    macro avg       0.93      0.94      0.93      1740
# weighted avg       0.94      0.93      0.93      1740

# %% [markdown]
# # Convert to model for Tensorflow-Lite

# %%
import os
import tensorflow as tf

try:
    if not os.path.exists(model_save_path):
        raise FileNotFoundError(f"Saved model file not found at {model_save_path}. Ensure the path is correct.")
    
    # Load the model
    model = tf.keras.models.load_model(model_save_path)
    print("Model loaded successfully.")

except FileNotFoundError as fnf_error:
    print(fnf_error)
    # Fallback or notify user for further action
    print("Please check the model save path or ensure the model file is available.")
    exit()

except OSError as os_error:
    print(f"Error loading model: {os_error}. This might be due to an incompatible TensorFlow version.")
    # Provide suggestion for potential fix
    print("Please check TensorFlow version compatibility or try re-saving the model.")
    exit()

except Exception as e:
    print(f"An unexpected error occurred: {e}")
    exit()
# Out:
# Model loaded successfully.

# %% [markdown]
# # Inference test

# %%
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()

# %%
# Get I / O tensor
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
interpreter.set_tensor(input_details[0]['index'], np.array([X_test[0]]))

# %%
# %%time
# Inference implementation
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]['index'])
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
print(np.squeeze(tflite_results))
print(np.argmax(np.squeeze(tflite_results)))
# Out:
# [1.5494089e-01 4.7580963e-03 2.9854893e-04 1.1382532e-02 8.2736522e-01
#  1.2546611e-03]
# 4
